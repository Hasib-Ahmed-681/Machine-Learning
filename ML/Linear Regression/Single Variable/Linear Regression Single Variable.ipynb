# %%
#supervised machine learning
#values continuous nature(numaric value)

# %%
import pandas as pd
import seaborn as sns
import sklearn
from sklearn import linear_model

# %%
df=pd.read_csv('insurance.csv')

# %%
df
# Out:
#    age  premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='age',y='premium',data=df)

# %%
reg=linear_model.LinearRegression()

# %%
# fit()-> train data , 2 dimensional
reg.fit(df[['age']],df['premium'])
# Out:
# LinearRegression()

# %%
reg.predict([[21]])
# Out:
# C:\Users\Hasib\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13480.])

# %%
reg.predict([[50]])
# Out:
# C:\Users\Hasib\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65100.])

# %%
#y=mx+c
m=reg.coef_
#m

# %%
c=reg.intercept_ 
#c

# %%
y=m*21+c
y
# Out:
# array([13480.])
